# %%
import boto3

def s3_connection():
    try:
        # s3 클라이언트 생성
        s3 = boto3.client(
            service_name="s3",
            region_name="ap-northeast-2",
            aws_access_key_id="AKIA2DNL3N7N4TJT6ZYA",
            aws_secret_access_key="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",
        )
    except Exception as e:
        print(e)
    else:
        print("s3 bucket connected!") 
        return s3
        
s3 = s3_connection()
# Out:
# s3 bucket connected!

# %%
bucket_name = "designovel"
prefix = 'image/'

# %%
prefix = 'image/'

def list_objects_in_prefix(s3, bucket_name, prefix):
    paginator = s3.get_paginator('list_objects_v2')
    operation_parameters = {'Bucket': bucket_name, 'Prefix': prefix}
    page_iterator = paginator.paginate(**operation_parameters)

    objects = []
    for page in page_iterator:
        if 'Contents' in page:
            for obj in page['Contents']:
                objects.append(obj['Key'])

    return objects

# %%
result = list_objects_in_prefix(s3, bucket_name, prefix)

# %%
result
# Out:
# ['image/handsome/BA2D9TTO001M/0.webp',
#  'image/handsome/BA2D9TTO001M/1.webp',
#  'image/handsome/BA2D9TTO001M/2.webp',
#  'image/handsome/BA2D9TTO001M/3.webp',
#  'image/handsome/BA2D9TTO001M/4.webp',
#  'image/handsome/BA2D9TTO001M/5.webp',
#  'image/handsome/BA2D9TTO001M/6.webp',
#  'image/handsome/BA2E1TTO001M/0.webp',
#  'image/handsome/BA2E1TTO001M/1.webp',
#  'image/handsome/BA2E1TTO001M/10.webp',
#  'image/handsome/BA2E1TTO001M/11.webp',
#  'image/handsome/BA2E1TTO001M/12.webp',
#  'image/handsome/BA2E1TTO001M/13.webp',
#  'image/handsome/BA2E1TTO001M/14.webp',
#  'image/handsome/BA2E1TTO001M/15.webp',
#  'image/handsome/BA2E1TTO001M/16.webp',
#  'image/handsome/BA2E1TTO001M/17.webp',
#  'image/handsome/BA2E1TTO001M/18.webp',
#  'image/handsome/BA2E1TTO001M/19.webp',
#  'image/handsome/BA2E1TTO001M/2.webp',
#  'image/handsome/BA2E1TTO001M/20.webp',
#  'image/handsome/BA2E1TTO001M/3.webp',
#  'image/handsome/BA2E1TTO001M/4.webp',
#  'image/handsome/BA2E1TTO001M/5.webp',
# ...

# %%
len(result)
# Out:
# 242414

# %%
file_path = "https://cdn.designovel.com/"

# %%
def fetch_cdn_url(file_path, result_list):
    img_urls = []
    for obj_key in result_list:
    # 객체 키에서 bucket_name과 prefix를 제거하여 상대 경로 생성
        relative_path = obj_key
        image_url = file_path + relative_path
        img_urls.append(image_url)
    return img_urls

# %%
cdn_urls = fetch_cdn_url(file_path, result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 cdn_urls = fetch_cdn_url(file_path, result)
#
# NameError: name 'result' is not defined

# %%
import psycopg2
from psycopg2.extras import execute_batch

conn = psycopg2.connect("dbname=version4 user=test password=5303 host=localhost")
cur = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[12], line 4
#       1 import psycopg2
#       2 from psycopg2.extras import execute_batch
# ----> 4 conn = psycopg2.connect("dbname=version4 user=test password=5303 host=localhost")
#       5 cur = conn.cursor()
#
# File c:\Users\test\.conda\envs\designovel2\lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?
# ...

# %%
import mysql.connector

# MySQL 데이터베이스 연결 설정
db_host = '127.0.0.1'
db_port = 33308
db_user = 'kwu'
db_password = '32tz6ylkxdgndhz6wmh75vj3'
db_name = 'kwu-devel'

# MySQL 데이터베이스 연결
conn = mysql.connector.connect(
    host=db_host,
    port=db_port,
    user=db_user,
    password=db_password,
    database=db_name
)

# 커서 생성
cursor = conn.cursor()

# SQL 쿼리 정의
sql_query = """
    SELECT DISTINCT s.style_id, c.name
    FROM category_style s
    JOIN category c ON c.category_id = s.category_id
"""

# SQL 쿼리 실행
cursor.execute(sql_query)

matrix = cursor.fetchall()

# 결과를 딕셔너리로 변환
mapping_dict = {style_id: name for style_id, name in matrix}

# 결과 출력
print(mapping_dict)

# 커넥션과 커서 닫기
cursor.close()
conn.close()
# Out:
# {'300951066': '맥시', '301168147': '맥시', '301687371': '맥시', '301687372': '맥시', '301687373': '맥시', '301692131': '맥시', '301700983': '맥시', '301707244': '맥시', '301709622': '맥시', '301709766': '맥시', '301711368': '맥시', '301717249': '맥시', '301722080': '맥시', '301730833': '맥시', '301730836': '맥시', '301732935': '맥시', '301751943': '맥시', '301754804': '맥시', '301795810': '맥시', '301798682': '맥시', '302280495': '맥시', '302280497': '맥시', '302280518': '맥시', '302301609': '맥시', '302304866': '맥시', '302363866': '맥시', '302547846': '맥시', '302615720': '맥시', '302616185': '맥시', '302715576': '맥시', '302743822': '맥시', '302743829': '맥시', '302743838': '맥시', '302768203': '맥시', '302768208': '맥시', '302768259': '맥시', '302792038': '맥시', '302809896': '맥시', '302816795': '맥시', '302862176': '맥시', '302862874': '맥시', '302900644': '맥시', '302905529': '맥시', '302906766': '맥시', '302917355': '맥시', '302980530': '맥시', '303049964': '맥시', '303100125': '맥시', '303125408': '맥시', '303129001': '맥시', '303195041': '맥시', '303195102': '맥시', '30319523
# ...

# %%
kor_to_eng = {
    '숏패딩 숏헤비 아우터': 'Short Padding Short Heavy Outerwear',
    '데님 팬츠': 'Denim Pants',
    '스웻': 'Sweat',
    '겨울 기타 코트': 'Winter Other Coats',
    'L?TT : 24SS VISIONARY': 'L?TT : 24SS VISIONARY',
    '치노': 'Chino',
    '풀오버': 'Pullover',
    '후드 집업': 'Hood Zip-up',
    "O'2nd : 24SS CROCHER PLAY": "O'2nd : 24SS CROCHER PLAY",
    '상의': 'Top',
    '로브': 'Robe',
    '블레이저': 'Blazer',
    '나시탑/캐미솔': 'Tank Top/Camisole',
    '블루종/MA-1': 'Blouson/MA-1',
    '겨울 더블 코트': 'Winter Double Coat',
    '트레이닝 재킷': 'Training Jacket',
    'OBZEE : 24SS ESSENTIAL': 'OBZEE : 24SS ESSENTIAL',
    '가디건/베스트': 'Cardigan/Vest',
    "O'2nd : 24SS DENIM PLAY": "O'2nd : 24SS DENIM PLAY",
    '펜슬': 'Pencil',
    '아노락 재킷': 'Anorak Jacket',
    '드로즈': 'Drawers',
    'SYSTEM HOMME : GLOBAL COLLECTION': 'SYSTEM HOMME : GLOBAL COLLECTION',
    'TIME HOMME : 23 SUMMER EXCLUSIVE': 'TIME HOMME : 23 SUMMER EXCLUSIVE',
    '루즈/테이퍼드': 'Loose/Tapered',
    'L?TT : CONTEMPORARY ESSENTIAL': 'L?TT : CONTEMPORARY ESSENTIAL',
    '재킷': 'Jacket',
    '니트/스웨터': 'Knit/Sweater',
    '스포츠 하의': 'Sports Bottoms',
    '미디스커트': 'Midi Skirt',
    'MINE : CODE MINE [ETERNAL GRACE]': 'MINE : CODE MINE [ETERNAL GRACE]',
    'TIME : The TIME': 'TIME : The TIME',
    "O'2nd : Brigitte Tanaka 콜라보": "O'2nd : Brigitte Tanaka Collaboration",
    '레더/라이더스 재킷': 'Leather/Riders Jacket',
    '카고': 'Cargo',
    '트렌치 코트': 'Trench Coat',
    '데님아우터': 'Denim Outerwear',
    '기타 아우터': 'Other Outerwear',
    '핸드메이드코트': 'Handmade Coat',
    '하의': 'Bottoms',
    '점프수트': 'Jumpsuit',
    '나일론/코치 재킷': 'Nylon/Coach Jacket',
    '코튼 팬츠': 'Cotton Pants',
    '터틀넥': 'Turtleneck',
    '파자마원피스': 'Pajama Dress',
    '스키니진': 'Skinny Jeans',
    '슬리브리스': 'Sleeveless',
    '후드 티셔츠': 'Hoodie',
    '슈트 팬츠/슬렉스': 'Suit Pants/Slacks',
    '셔츠/블라우스': 'Shirt/Blouse',
    'TIME HOMME : 23 FALL EXCLUSIVE': 'TIME HOMME : 23 FALL EXCLUSIVE',
    '스트레이트': 'Straight',
    'SYSTEM : GLOBAL COLLECTION': 'SYSTEM : GLOBAL COLLECTION',
    '민소매 티셔츠': 'Sleeveless T-shirt',
    '포멀': 'Formal',
    '다운/패딩': 'Down/Padding',
    '스포츠 상의': 'Sports Tops',
    '겨울 싱글 코트': 'Winter Single Coat',
    '셔츠': 'Shirt',
    '스트레이트진': 'Straight Jeans',
    '카디건': 'Cardigan',
    '미디': 'Midi',
    'MINE : STEADY MINE': 'MINE : STEADY MINE',
    '티셔츠': 'T-shirt',
    "O'2nd : 24SS ONE-PIECE PLAY": "O'2nd : 24SS ONE-PIECE PLAY",
    '플레어': 'Flare',
    '트레이닝/조거': 'Training/Jogger',
    '파자마하의': 'Pajama Bottoms',
    '후드집업': 'Hood Zip-up',
    '반소매 티셔츠': 'Short Sleeve T-shirt',
    'the CASHMERE : 24SS CLUB15': 'the CASHMERE : 24SS CLUB15',
    '조거/트랙': 'Jogger/Track',
    '와이드진': 'Wide Jeans',
    'MINE : CODE MINE [Meaningful Moment]': 'MINE : CODE MINE [Meaningful Moment]',
    '무스탕': 'Mustang',
    '조거': 'Jogger',
    '원피스': 'Dress',
    'OBZEE : 24SS ICONIC': 'OBZEE : 24SS ICONIC',
    '레더': 'Leather',
    '니트': 'Knit',
    '반팔': 'Short Sleeve',
    '미니': 'Mini',
    '카라': 'Collar',
    '레깅스': 'Leggings',
    '롱패딩/롱헤비 아우터': 'Long Padding/Long Heavy Outerwear',
    '블라우스': 'Blouse',
    '플리스/뽀글이': 'Fleece/Boucle',
    '사파리/헌팅 재킷': 'Safari/Hunting Jacket',
    'LANVIN COLLECTION : 24SS LVC': 'LANVIN COLLECTION : 24SS LVC',
    'OBZEE : STUNNING MOMENT': 'OBZEE : STUNNING MOMENT',
    '와이드': 'Wide',
    '숏 팬츠': 'Shorts',
    '캐시미어': 'Cashmere',
    '트렌치코트': 'Trench Coat',
    '브라렛': 'Bralette',
    '패딩': 'Padding',
    '데님': 'Denim',
    '긴소매 티셔츠': 'Long Sleeve T-shirt',
    '긴팔': 'Long Sleeve',
    '롱': 'Long',
    '스웻셔츠': 'Sweatshirt',
    '트레이닝/조거 팬츠': 'Training/Jogger Pants',
    '와이어브라': 'Underwire Bra',
    '캐주얼': 'Casual',
    '파자마세트': 'Pajama Set',
    "O'2nd : 24SS VOYAGEUR": "O'2nd : 24SS VOYAGEUR",
    '트렁크': 'Trunks',
    '수트재킷': 'Suit Jacket',
    '트러커 재킷': 'Trucker Jacket',
    '셋업': 'Setup',
    '슈트/블레이저 재킷': 'Suit/Blazer Jacket',
    '스타디움 재킷': 'Stadium Jacket',
    '환절기 코트': 'Transitional Coat',
    '롱스커트': 'Long Skirt',
    '패딩 베스트': 'Padded Vest',
    '쇼츠': 'Shorts',
    '수트팬츠': 'Suit Pants',
    '크롭진': 'Cropped Jeans',
    'TIME HOMME : 23 WINTER EXCLUSIVE': 'TIME HOMME : 23 WINTER EXCLUSIVE',
    '자켓': 'Jacket',
    '피케/카라 티셔츠': 'Pique/Collar T-shirt',
    'SJSJ : CITY CAPSULE MONACO': 'SJSJ : CITY CAPSULE MONACO',
    'TIME HOMME : 24 SPRING EXCLUSIVE': 'TIME HOMME : 24 SPRING EXCLUSIVE',
    '무스탕/퍼': 'Mustang/Fur',
    '보이프렌드진': 'Boyfriend Jeans',
    '파자마상의': 'Pajama Top',
    '롱/맥시': 'Long/Maxi',
    '맨투맨/스웨트셔츠': 'Sweatshirt',
    '슬랙스': 'Slacks',
    '세트': 'Set',
    '맥시': 'Maxi',
    '슬림/스트레이트': 'Slim/Straight',
    '스커트': 'Skirt',
    '후드': 'Hoodie',
    '기타 바지': 'Other Pants',
    '점프 슈트/오버울': 'Jumpsuit/Overall',
    '아우터': 'Outerwear',
    '미니스커트': 'Mini Skirt',
    '기타 상의': 'Other Tops',
    '베스트': 'Vest',
    '점퍼': 'Jumper',
    '부츠컷진': 'Bootcut Jeans',
    '탑': 'Top',
    '코트': 'Coat',
    'SJSJ : CITY CAPSULE GRASSE': 'SJSJ : CITY CAPSULE GRASSE',
    '팬티': 'Panties',
    '가디건': 'Cardigan'
}

# %%
# # 테이블 초기화. 테스트용
# cur.execute("TRUNCATE TABLE version4;")
# conn.commit()

# %%
# mapping_dict의 값을 kor_to_eng 딕셔너리를 사용하여 매핑하기
mapped_dict = {style_id: kor_to_eng[name] for style_id, name in mapping_dict.items()}

# 매핑된 결과 출력
print(mapped_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # mapping_dict의 값을 kor_to_eng 딕셔너리를 사용하여 매핑하기
# ----> 2 mapped_dict = {style_id: kor_to_eng[name] for style_id, name in mapping_dict.items()}
#       4 # 매핑된 결과 출력
#       5 print(mapped_dict)
#
# NameError: name 'mapping_dict' is not defined

# %%
mapped_list = list(mapped_dict.items())
mapped_list[49]
# Out:
# ('303129001', 'Maxi')

# %%
cdn_urls[50]
# Out:
# 'https://cdn.designovel.com/image/handsome/BA2E3NPC001MSR/1.webp'

# %%
import matplotlib.pyplot as plt
from PIL import Image
from util.extract_image_feature import process_image_and_feature
from IPython.display import display

for cdn_url in cdn_urls[:1]:
    parts = cdn_url.split('/')
    style_id = parts[-2]
    
    # mapping_dict에서 style_id에 해당하는 category를 찾기
    category = mapped_dict.get(style_id, '')

    # 이미지와 피처 처리 함수 호출
    image, vec = process_image_and_feature(cdn_url, category)
    print(category)
    display(image)
    
    # print(f"URL: {cdn_url}, Style ID: {style_id}, Category: {category}, Vector: {vec}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import matplotlib.pyplot as plt
#       2 from PIL import Image
# ----> 3 from image_search import process_image_and_feature
#       4 from IPython.display import display
#       6 for cdn_url in cdn_urls[:1]:
#
# ModuleNotFoundError: No module named 'image_search'

# %%
import psycopg2
from psycopg2 import extras
from image_search import process_image_and_feature

# 데이터베이스 연결 설정
conn = psycopg2.connect("dbname=imagevector user=test password=5303 host=localhost")
conn.autocommit = True
cur = conn.cursor()

# %%
cdn_url = []

# %%
# 삽입할 데이터를 저장할 리스트
data_to_insert = []

# 각 CDN URL 처리
for i, cdn_url in enumerate(cdn_urls):
    parts = cdn_url.split('/')
    style_id = parts[-2]
    
    # mapping_dict에서 style_id에 해당하는 category를 찾기
    category = mapped_dict.get(style_id, '')

    # 이미지와 피처 처리 함수 호출
    image, vec = process_image_and_feature(cdn_url, category)
    vec = vec.cpu().numpy().tolist()
    
    data_to_insert.append((style_id, category, vec, cdn_url))
    print(f'{i}번째 완료')

    # 데이터 베이스에 배치로 삽입
    if len(data_to_insert) >= 100:  # 100개 묶음으로 삽입, 필요에 따라 조절 가능
        psycopg2.extras.execute_batch(cur, """
            INSERT INTO version4 (style_id, category, embedding, cdn_url) 
            VALUES (%s, %s, %s, %s)
            ON CONFLICT (cdn_url) DO NOTHING
        """, data_to_insert)
        conn.commit()
        
        print('100개 아이템 데이터베이스에 삽입 완료')
        data_to_insert = []  # 삽입 후 리스트 초기화
        
# 남은 데이터가 있다면 삽입
if data_to_insert:
    psycopg2.extras.execute_batch(cur, """
        INSERT INTO version4 (style_id, category, embedding, cdn_url) 
        VALUES (%s, %s, %s, %s)
        ON CONFLICT (cdn_url) DO NOTHING
    """, data_to_insert)
    conn.commit()
    print('잔여 데이터 데이터베이스에 삽입 완료')
# Out:
# SupervisionWarnings: annotate is deprecated: `BoxAnnotator` is deprecated and will be removed in `supervision-0.22.0`. Use `BoundingBoxAnnotator` and `LabelAnnotator` instead
# 0번째 완료
# SupervisionWarnings: annotate is deprecated: `BoxAnnotator` is deprecated and will be removed in `supervision-0.22.0`. Use `BoundingBoxAnnotator` and `LabelAnnotator` instead
# 1번째 완료
# SupervisionWarnings: annotate is deprecated: `BoxAnnotator` is deprecated and will be removed in `supervision-0.22.0`. Use `BoundingBoxAnnotator` and `LabelAnnotator` instead
# 2번째 완료
# SupervisionWarnings: annotate is deprecated: `BoxAnnotator` is deprecated and will be removed in `supervision-0.22.0`. Use `BoundingBoxAnnotator` and `LabelAnnotator` instead
# 3번째 완료
# SupervisionWarnings: annotate is deprecated: `BoxAnnotator` is deprecated and will be removed in `supervision-0.22.0`. Use `BoundingBoxAnnotator` and `LabelAnnotator` instead
# 4번째 완료
# ...
